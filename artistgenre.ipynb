# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyOAuth
from datetime import datetime, timedelta

import spotipy
from spotipy.oauth2 import SpotifyOAuth
from datetime import datetime, timedelta
import math 
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from collections import Counter
import time

# Initialize the Spotify API client
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id="f6f6de34e09741d28b1766703ec2560a",
                                               client_secret="19cd0d5906204557934a27406a24e4ca",
                                               redirect_uri="http://localhost:8888/callback",
                                               scope="user-library-read playlist-modify-public playlist-read-private",
                                               requests_timeout=30))

# %%
from spotipy import Spotify
from spotipy.oauth2 import SpotifyClientCredentials

def get_artist_genres(artist_name):
    
    # Authenticate with Spotify API
    spotify = sp

    # Search for the artist by name
    results = spotify.search(q=f"artist:{artist_name}", type='artist', limit=1)
    artists = results.get('artists', {}).get('items', [])

    if not artists:
        print(f"No artist found with the name: {artist_name}")
        return []

    # Get the first artist from the results
    artist = artists[0]
    genres = artist.get('genres', [])

    print(f"Genres for {artist_name}: {genres}")
    return genres

# Input the artist name
artist_name = "Ben Howard "#input("Enter the artist's name: ").strip()

# Fetch and display genres
get_artist_genres(artist_name)
# Out:
# Genres for Ben Howard : ['british singer-songwriter', 'folk-pop', 'indie folk']
# ['british singer-songwriter', 'folk-pop', 'indie folk']
